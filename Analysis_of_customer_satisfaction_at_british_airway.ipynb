# %% [markdown]
# **British Airways**
#
#
# **Task 1**
#
# Web scraping to gain company insights Scrape and analyse customer review data to uncover findings for British Airways

# %% [markdown]
# Scrape data from the web

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

from wordcloud import WordCloud 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 50 #10
page_size = 100 #100

reviews = []
aircraft = []
seat_type = []
route = []
recommended = []
df = pd.DataFrame()

# for i in range(1, pages + 1):
for i in range(1, pages + 1):
    
    rating = []
    category = []

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
        
    for para2 in parsed_content.find_all("div", {"class" : "review-stats"}):
        for para3 in para2.find_all('td',{'class' : 'review-value'}):
            rating.append(para3.get_text())
        recomend = rating[-1]
        rating = rating[:-1]
        
        for para4 in para2.find_all('td',{'class' : 'review-rating-stars stars'}):
            para5 = len(para4.find_all('span', {'class' : 'star fill'}))
            rating.append(para5)
        rating.append(recomend)
        #print(rating)
        
        for para6 in para2.find_all('td',{'class' : 'review-rating-header'}):
            category.append(para6.get_text())
            
        #print(category)
        # Create the records from both list, using zip and dict calls.

        # Build the dataframe from the dictionary.
        data_dict = pd.DataFrame([rating], columns=category)
        df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
        #print(df)
        rating = []
        category = []
        
    print(f"   ---> {len(reviews)} total reviews")

df["reviews"] = reviews
# Out:
# Scraping page 1
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
#    ---> 100 total reviews
# Scraping page 2
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
#    ---> 200 total reviews
# Scraping page 3
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# ...
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
#    ---> 3500 total reviews
# Scraping page 36
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# <ipython-input-2-e789d75da194>:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
#    ---> 3541 total reviews
# Scraping page 37
#    ---> 3541 total reviews
# Scraping page 38
#    ---> 3541 total reviews
# Scraping page 39
#    ---> 3541 total reviews
# Scraping page 40
#    ---> 3541 total reviews
# Scraping page 41
#    ---> 3541 total reviews
# Scraping page 42
#    ---> 3541 total reviews
# Scraping page 43
#    ---> 3541 total reviews
# Scraping page 44
#    ---> 3541 total reviews
# Scraping page 45
#    ---> 3541 total reviews
# Scraping page 46
#    ---> 3541 total reviews
# Scraping page 47
#    ---> 3541 total reviews
# Scraping page 48
#    ---> 3541 total reviews
# Scraping page 49
#    ---> 3541 total reviews
# Scraping page 50
#    ---> 3541 total reviews

# %%
df.tail()
# Out:
#      Aircraft Type Of Traveller        Seat Type Route Date Flown  \
# 3536      NaN               NaN   Business Class   NaN        NaN
# 3537      NaN               NaN   Business Class   NaN        NaN
# 3538      NaN               NaN    Economy Class   NaN        NaN
# 3539      NaN               NaN  Premium Economy   NaN        NaN
# 3540      NaN               NaN      First Class   NaN        NaN
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 3536           4.0                  3.0               2.0
# 3537           4.0                  5.0               4.0
# 3538           NaN                  NaN               NaN
# 3539           1.0                  3.0               5.0
# 3540           4.0                  5.0               5.0
#
#       Inflight Entertainment  Ground Service  Wifi & Connectivity  \
# 3536                     4.0             NaN                  NaN
# 3537                     0.0             NaN                  NaN
# 3538                     NaN             NaN                  NaN
# 3539                     0.0             NaN                  NaN
# 3540                     2.0             NaN                  NaN
#
#       Value For Money Recommended  \
# 3536                3         yes
# 3537                3         yes
# 3538                4         yes
# 3539                1          no
# 3540                2          no
#
#                                                 reviews
# 3536  Flew return in CW from LHR to BKK in August 20...
# 3537  LHR to HAM. Purser addresses all club passenge...
# 3538  My son who had worked for British Airways urge...
# 3539  London City-New York JFK via Shannon on A318 b...
# 3540  SIN-LHR BA12 B747-436 First Class. Old aircraf...

# %%
df.to_csv("BA_reviews.csv", index=False)

# %%
df = pd.read_csv('BA_reviews.csv')

# %% [markdown]
# **Data Cleaning**

# %%
df.shape
# Out:
# (3541, 14)

# %%
remove_text = ['✅ Trip Verified', 'Not Verified |']

for i in range(len(df['reviews'])):
    for j in remove_text:
        if j in df['reviews'][i]:
            df['reviews'] = df['reviews'].str.replace(j,'')
# Out:
# <ipython-input-7-6b7437e0fbc7>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['reviews'] = df['reviews'].str.replace(j,'')

# %%
df.sample(5)
# Out:
#         Aircraft Type Of Traveller      Seat Type               Route  \
# 3137         NaN               NaN  Economy Class                 NaN
# 3142         NaN               NaN  Economy Class                 NaN
# 1882  Boeing 747      Solo Leisure    First Class          LHR to BOS
# 637          NaN          Business  Economy Class   London to Glasgow
# 162   Boeing 787    Couple Leisure  Economy Class  Tel Aviv to London
#
#         Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 3137           NaN           3.0                  3.0               3.0
# 3142           NaN           4.0                  5.0               4.0
# 1882  October 2016           4.0                  4.0               3.0
# 637      June 2019           2.0                  2.0               3.0
# 162    August 2022           5.0                  5.0               5.0
#
#       Inflight Entertainment  Ground Service  Wifi & Connectivity  \
# 3137                     4.0             NaN                  NaN
# 3142                     1.0             NaN                  NaN
# 1882                     4.0             4.0                  3.0
# 637                      NaN             1.0                  NaN
# 162                      5.0             3.0                  NaN
#
#       Value For Money Recommended  \
# 3137                2          no
# 3142                4         yes
# 1882                4         yes
# 637                 1          no
# 162                 4         yes
#
#                                                 reviews
# 3137  I had a very poor experience with BA from Jo'b...
# 3142  Flew BA to Munich. Quick check-in good boardin...
# 1882  ✅ Verified Review |  I had a perfectly satisfa...
# 637    |  London to Glasgow. BA customer service is ...
# 162    |  Full afternoon flight. Ready to fly on tim...

# %% [markdown]
# Analysis Data

# %% [markdown]
# wordclouds

# %%
review_word = []

for i in df['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# Satisfaction of customer

# %%
soc = df.groupby('Recommended')['reviews'].count().reset_index()
plt.pie(soc['reviews'], labels = soc['Recommended'], autopct='%.2f%%',colors = sns.color_palette('pastel'),
          wedgeprops={"edgecolor":"k"},)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

soc = df.groupby('Recommended')['reviews'].count().reset_index()

plt.bar(soc['Recommended'], soc['reviews'], color=sns.color_palette('pastel'))
plt.xlabel('Recommended')
plt.ylabel('Number of Reviews')

plt.show()

# %% [markdown]
# View rating of BA service by passenger that dissatisfied with British Airways

# %%
df_soc = df[df['Recommended'] == 'no']
df_soc.describe()
# Out:
#        Seat Comfort  Cabin Staff Service  Food & Beverages  \
# count   1974.000000          1964.000000       1770.000000
# mean       2.129686             2.431772          1.822034
# std        1.085032             1.281924          0.999418
# min        1.000000             1.000000          0.000000
# 25%        1.000000             1.000000          1.000000
# 50%        2.000000             2.000000          1.000000
# 75%        3.000000             3.000000          2.000000
# max        5.000000             5.000000          5.000000
#
#        Inflight Entertainment  Ground Service  Wifi & Connectivity  \
# count             1385.000000     1689.000000           391.000000
# mean                 2.026715        2.130255             1.462916
# std                  1.133442        1.212432             0.921554
# min                  0.000000        1.000000             1.000000
# 25%                  1.000000        1.000000             1.000000
# 50%                  2.000000        2.000000             1.000000
# 75%                  3.000000        3.000000             1.000000
# max                  5.000000        5.000000             5.000000
#
#        Value For Money
# count      2074.000000
# mean          1.741562
# std           0.914976
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           5.000000

# %% [markdown]
# Analysis food on airways

# %%
data = df_soc[df_soc['reviews'].str.contains('food | drink')]
data['reviews'].to_csv('test.csv')

# %%
review_word = []

for i in data['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
soc = data.groupby('Recommended')['reviews'].count().reset_index()
plt.pie(soc['reviews'], labels = soc['Recommended'], autopct='%.2f%%',colors = sns.color_palette('pastel'),
          wedgeprops={"edgecolor":"k"},)
plt.legend()
plt.show()

# %% [markdown]
# Analysis value for money

# %%
data = df_soc[df_soc['reviews'].str.contains('money | refund & value')]
data['reviews'].to_csv('test2.csv')

# %%
review_word = []

for i in data['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
soc = data.groupby('Recommended')['reviews'].count().reset_index()
plt.pie(soc['reviews'], labels = soc['Recommended'], autopct='%.2f%%',colors = sns.color_palette('pastel'),
          wedgeprops={"edgecolor":"k"},)
plt.legend()
plt.show()
